# %%
### Data INGESTION

# %%
from langchain_core.documents import Document

# %%
doc = Document(
    page_content="this is the main test i am using to create rag",
    metadata = {
        "source" : "example.txt",
        "pages" : 10,
        "author" : "rhythem sabharwal"
    }
)
print(doc)
# Out:
# page_content='this is the main test i am using to create rag' metadata={'source': 'example.txt', 'pages': 10, 'author': 'rhythem sabharwal'}

# %%
import os 

# Go up one level from 'notebook' to 'Understanding', then make the 'data/text_files' directory
os.makedirs("../data/text_files", exist_ok=True) 

sample_texts = {
    "../data/text_files/python_intro.txt": """Python Programming Introduction

Python is a high-level, interpreted programming language known for its simplicity and readability.
Created by Guido van Rossum and first released in 1991, Python has become one of the most popular
programming languages in the world.

Key Features:
- Easy to learn and use
- Extensive standard library
- Cross-platform compatibility
- Strong community support

Python is widely used in web development, data science, artificial intelligence, and automation.""",
    
    "../data/text_files/machine_learning.txt": """Machine Learning Basics

Machine learning is a subset of artificial intelligence that enables systems to learn and improve
from experience without being explicitly programmed. It focuses on developing computer programs
that can access data and use it to learn for themselves.

Types of Machine Learning:
1. Supervised Learning: Learning with labeled data
2. Unsupervised Learning: Finding patterns in unlabeled data
3. Reinforcement Learning: Learning through rewards and penalties

Applications include image recognition, speech processing, and recommendation systems"""
}

for filepath, content in sample_texts.items():
    with open(filepath, 'w', encoding="utf-8") as f:
        f.write(content)

print("✅ Sample text files created!")
# Out:
# ✅ Sample text files created!

# %%
from langchain_community.document_loaders import TextLoader      

loader = TextLoader("../data/text_files/python_intro.txt", encoding="utf-8")
# Out:
# /var/folders/ny/1v8103651lxbgv3ms88n0yyw0000gn/T/ipykernel_1524/2739941320.py:1: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.document_loaders import TextLoader

# %%
### Directory Loader
from langchain_community.document_loaders import DirectoryLoader

## load all the text files from the directory
dir_loader=DirectoryLoader(
    "../data/text_files",
    glob="**/*.txt", ## Pattern to match files  
    loader_cls= TextLoader, ##loader class to use
    loader_kwargs={'encoding': 'utf-8'},
    show_progress=False

)

documents=dir_loader.load()
documents
# Out:
# [Document(metadata={'source': '../data/text_files/python_intro.txt'}, page_content='Python Programming Introduction\n\nPython is a high-level, interpreted programming language known for its simplicity and readability.\nCreated by Guido van Rossum and first released in 1991, Python has become one of the most popular\nprogramming languages in the world.\n\nKey Features:\n- Easy to learn and use\n- Extensive standard library\n- Cross-platform compatibility\n- Strong community support\n\nPython is widely used in web development, data science, artificial intelligence, and automation.'),
#  Document(metadata={'source': '../data/text_files/machine_learning.txt'}, page_content='Machine Learning Basics\n\nMachine learning is a subset of artificial intelligence that enables systems to learn and improve\nfrom experience without being explicitly programmed. It focuses on developing computer programs\nthat can access data and use it to learn for themselves.\n\nTypes of Machine Learning:\n1. Supervised Learning: Learning with labeled data\n2. Unsupervised Learning: Finding patterns in unlabeled data\n3. Reinforcement Learning: Learning through rewards and penalties\n\nApplications include image recognition, speech processing, and recommendation systems')]

# %%
from langchain_community.document_loaders import PyPDFLoader, PyMuPDFLoader

## load all the text files from the directory
dir_loader=DirectoryLoader(
    "../data/pdf",
    glob="**/*.pdf", ## Pattern to match files  
    loader_cls= PyMuPDFLoader, ##loader class to use
    show_progress=False

)

pdf_documents=dir_loader.load()
pdf_documents
# Out:
# [Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2024-07-07T12:50:10+00:00', 'source': '../data/pdf/sample-10-page-pdf-a4-size.pdf', 'file_path': '../data/pdf/sample-10-page-pdf-a4-size.pdf', 'total_pages': 10, 'format': 'PDF 1.4', 'title': 'Sample 10-Page PDF A4 Size | Sample-Files.com', 'author': 'Jericho', 'subject': '', 'keywords': 'DAGKQlAebtI,BAEVm-WErFA', 'moddate': '2024-07-07T12:50:09+00:00', 'trapped': '', 'modDate': "D:20240707125009+00'00'", 'creationDate': "D:20240707125010+00'00'", 'page': 0}, page_content='SmartHome Hub\nSmartHome Hub, Inc\nAlex Johnson\nPrepared By\nhttps://sample-files.com\n+123-456-7890\nProduct Launch Strategy'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2024-07-07T12:50:10+00:00', 'source': '../data/pdf/sample-10-page-pdf-a4-size.pdf', 'file_path': '../data/pdf/sample-10-page-pdf-a4-size.pdf', 'total_pages': 10, 'format': 'PDF 1.4', 'title': 'Sample 10-Page PDF A4 Size | Sample-Files.com', 'author': 'Jericho', 'subject': '', 'keywords': 'DAGKQlAebtI,BAEVm-WErFA', 'moddate': '2024-07-07T12:50:09+00:00', 'trapped': '', 'modDate': "D:20240707125009+00'00'", 'creationDate': "D:20240707125010+00'00'", 'page': 1}, page_content='Table of Contents\n1. Executive Summary\n2. Introduction\n3. Product Overview\n4. Market Analysis\n5. Competitor Analysis\n6. Marketing Strategy\n7. Sales Projections\n8. Launch Timeline'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2024-07-07T12:50:10+00:00', 'source': '../data/pdf/sample-10-page-pdf-a4-size.pdf', 'file_path': '../data/pdf/sample-10-page-pdf-a4-size.pdf', 'total_pages': 10, 'format': 'PDF 1.4', 'title': 'Sample 10-Page PDF A4 Size | Sample-Files.com', 'author': 'Jericho', 'subject': '', 'keywords': 'DAGKQlAebtI,BAEVm-WErFA', 'moddate': '2024-07-07T12:50:09+00:00', 'trapped': '', 'modDate': "D:20240707125009+00'00'", 'creationDate': "D:20240707125010+00'00'", 'page': 2}, page_content='Executive Summary\nLorem ipsum dolor sit amet, consectetur adipiscing\n elit. Cras facilisis consectetur tempor. Aenean alique\nt sapien ex, pharetra consequat arcu tristique vitae. Nam quis porta ex. Donec porttitor at sem nec sollicitudin. Ut vel commodo tortor, sagittis egestas nisl. Donec quam mauris, tristique non tempus vitae, ornare sed mauris. Etiam blandit tempor metus, at vehicula nisi. Maecenas suscipit vulputate varius .\nNam lacinia leo felis, quis hendrerit tortor dignissim\n quis. Morbi egestas rhoncus lectus. Ut nec mauri\ns diam. Aenean gravida, est non ornare interdum, libe\nro nibh accumsan nibh, sed commodo erat orci ac tellus. Aenean iaculis urna nec metus sodales consectetur. Quisque lacinia dui vitae purus condimentum dapibus. Pellentesque habitant morbi tristique senectus et netus et malesuada fames ac turpis egesta s.'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2024-07-07T12:50:10+00:00', 'source': '../data/pdf/sample-10-page-pdf-a4-size.pdf', 'file_path': '../data/pdf/sample-10-page-pdf-a4-size.pdf', 'total_pages': 10, 'format': 'PDF 1.4', 'title': 'Sample 10-Page PDF A4 Size | Sample-Files.com', 'author': 'Jericho', 'subject': '', 'keywords': 'DAGKQlAebtI,BAEVm-WErFA', 'moddate': '2024-07-07T12:50:09+00:00', 'trapped': '', 'modDate': "D:20240707125009+00'00'", 'creationDate': "D:20240707125010+00'00'", 'page': 3}, page_content='Introduction\nNam quis porta ex. Donec porttitor at sem nec\n sollicitudin. Ut vel commodo tortor, sagittis egesta\ns nisl. Donec quam mauris, tristique non tempus vita\ne, ornare sed mauris. Etiam blandit tempor metus, at \nvehicula nisi. Maecenas suscipit vulputate varius.'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2024-07-07T12:50:10+00:00', 'source': '../data/pdf/sample-10-page-pdf-a4-size.pdf', 'file_path': '../data/pdf/sample-10-page-pdf-a4-size.pdf', 'total_pages': 10, 'format': 'PDF 1.4', 'title': 'Sample 10-Page PDF A4 Size | Sample-Files.com', 'author': 'Jericho', 'subject': '', 'keywords': 'DAGKQlAebtI,BAEVm-WErFA', 'moddate': '2024-07-07T12:50:09+00:00', 'trapped': '', 'modDate': "D:20240707125009+00'00'", 'creationDate': "D:20240707125010+00'00'", 'page': 4}, page_content='Product Overview\nNam quis porta ex. Donec porttitor at sem nec\n sollicitudin. Ut vel commodo tortor, sagittis egesta\ns nisl. Donec quam mauris, tristique non tempus vita\ne, ornare sed mauris. Etiam blandit tempor metus, at \nvehicula nisi. Maecenas suscipit vulputate varius.\nInteger et justo velus.\nUt in ipsum ac risus.\nMaecenas iaculis.\nUt nec mauris vel.\nTellus accumsan.\nKey Features\nInteger et justo velus.\nUt in ipsum ac risus.\nMaecenas iaculis.\nUt nec mauris vel.\nTellus accumsan.\nKey Features'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2024-07-07T12:50:10+00:00', 'source': '../data/pdf/sample-10-page-pdf-a4-size.pdf', 'file_path': '../data/pdf/sample-10-page-pdf-a4-size.pdf', 'total_pages': 10, 'format': 'PDF 1.4', 'title': 'Sample 10-Page PDF A4 Size | Sample-Files.com', 'author': 'Jericho', 'subject': '', 'keywords': 'DAGKQlAebtI,BAEVm-WErFA', 'moddate': '2024-07-07T12:50:09+00:00', 'trapped': '', 'modDate': "D:20240707125009+00'00'", 'creationDate': "D:20240707125010+00'00'", 'page': 5}, page_content='Market Analysis\nNam quis porta ex. Donec porttitor at sem nec\n sollicitudin. Ut vel commodo tortor, sagittis egesta\ns nisl. Donec quam mauris, tristique non tempus vita\ne, ornare sed mauris. Etiam blandit tempor metus, at \nvehicula nisi. Maecenas suscipit vulputate varius.\nCurrent market share\nProjected sales for the\nfirst three years'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2024-07-07T12:50:10+00:00', 'source': '../data/pdf/sample-10-page-pdf-a4-size.pdf', 'file_path': '../data/pdf/sample-10-page-pdf-a4-size.pdf', 'total_pages': 10, 'format': 'PDF 1.4', 'title': 'Sample 10-Page PDF A4 Size | Sample-Files.com', 'author': 'Jericho', 'subject': '', 'keywords': 'DAGKQlAebtI,BAEVm-WErFA', 'moddate': '2024-07-07T12:50:09+00:00', 'trapped': '', 'modDate': "D:20240707125009+00'00'", 'creationDate': "D:20240707125010+00'00'", 'page': 6}, page_content='Competitor Analysis\nVivamus orci mi, venenatis quis diam sed, scelerisque\n accumsan lacus. Curabitur eu dictum neque, sit ame\nt rutrum velit. In aliquam orci a ante hendrerit, v\nel egestas ligula interdum. Ut pulvinar ornare dapibus. Suspendisse nec cursus libero, at hendrerit ero s.'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2024-07-07T12:50:10+00:00', 'source': '../data/pdf/sample-10-page-pdf-a4-size.pdf', 'file_path': '../data/pdf/sample-10-page-pdf-a4-size.pdf', 'total_pages': 10, 'format': 'PDF 1.4', 'title': 'Sample 10-Page PDF A4 Size | Sample-Files.com', 'author': 'Jericho', 'subject': '', 'keywords': 'DAGKQlAebtI,BAEVm-WErFA', 'moddate': '2024-07-07T12:50:09+00:00', 'trapped': '', 'modDate': "D:20240707125009+00'00'", 'creationDate': "D:20240707125010+00'00'", 'page': 7}, page_content='Marketing Strategy\nTristique non tempus vitae, ornare sed mauris. Etiam\n blandit tempor metus, at vehicula nisi. Maecena\ns s uscipit vulputate varius.\nInteger et justo velus.\nUt in ipsum ac risus.\nMaecenas iaculis.\nUt nec mauris vel.\nTellus accumsan.\n1st Strategy\nInteger et justo velus.\nUt in ipsum ac risus.\nMaecenas iaculis.\nUt nec mauris vel.\nTellus accumsan.\n 2nd Strategy'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2024-07-07T12:50:10+00:00', 'source': '../data/pdf/sample-10-page-pdf-a4-size.pdf', 'file_path': '../data/pdf/sample-10-page-pdf-a4-size.pdf', 'total_pages': 10, 'format': 'PDF 1.4', 'title': 'Sample 10-Page PDF A4 Size | Sample-Files.com', 'author': 'Jericho', 'subject': '', 'keywords': 'DAGKQlAebtI,BAEVm-WErFA', 'moddate': '2024-07-07T12:50:09+00:00', 'trapped': '', 'modDate': "D:20240707125009+00'00'", 'creationDate': "D:20240707125010+00'00'", 'page': 8}, page_content='Sales Projections\nTristique non tempus vitae, ornare sed mauris. Etiam\n blandit tempor metus, at vehicula nisi. Maecena\ns s uscipit vulputate varius.\nMetric\nSales\nMarket Size\n$50 Billion\nUser Satisfaction\n85%\nGrowth Rate\n10%\nSeries 1\nSeries 2\nItem 1\nItem 2\nItem 3\n0\n5\n10\n15\n20'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2024-07-07T12:50:10+00:00', 'source': '../data/pdf/sample-10-page-pdf-a4-size.pdf', 'file_path': '../data/pdf/sample-10-page-pdf-a4-size.pdf', 'total_pages': 10, 'format': 'PDF 1.4', 'title': 'Sample 10-Page PDF A4 Size | Sample-Files.com', 'author': 'Jericho', 'subject': '', 'keywords': 'DAGKQlAebtI,BAEVm-WErFA', 'moddate': '2024-07-07T12:50:09+00:00', 'trapped': '', 'modDate': "D:20240707125009+00'00'", 'creationDate': "D:20240707125010+00'00'", 'page': 9}, page_content='Launch Timeline\nVivamus ac nunc vitae nulla molestie sodales. Proin sit\n amet rhoncus lacus. Cras non erat imperdiet sapien \nporttitor aliquam nec ut velit.'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2024-07-07T12:07:05+00:00', 'source': '../data/pdf/sample-5-page-pdf-a4-size.pdf', 'file_path': '../data/pdf/sample-5-page-pdf-a4-size.pdf', 'total_pages': 5, 'format': 'PDF 1.4', 'title': 'Sample 5-Page PDF A4 Size | Sample-Files.com', 'author': 'Jericho', 'subject': '', 'keywords': 'DAGKRGfiZEo,BAEVm-WErFA', 'moddate': '2024-07-07T12:07:04+00:00', 'trapped': '', 'modDate': "D:20240707120704+00'00'", 'creationDate': "D:20240707120705+00'00'", 'page': 0}, page_content='Innovative Tech\nSolutions, Inc.\nProduct Launch Report:\nSmartHome Hub\nPrepared by:\nAlex Johnson\nsample-files.com\n+1-555-123-4567'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2024-07-07T12:07:05+00:00', 'source': '../data/pdf/sample-5-page-pdf-a4-size.pdf', 'file_path': '../data/pdf/sample-5-page-pdf-a4-size.pdf', 'total_pages': 5, 'format': 'PDF 1.4', 'title': 'Sample 5-Page PDF A4 Size | Sample-Files.com', 'author': 'Jericho', 'subject': '', 'keywords': 'DAGKRGfiZEo,BAEVm-WErFA', 'moddate': '2024-07-07T12:07:04+00:00', 'trapped': '', 'modDate': "D:20240707120704+00'00'", 'creationDate': "D:20240707120705+00'00'", 'page': 1}, page_content='Introduction\nThis report outlines the launch strategy for\n our new SmartHome Hub, a central devic\ne designed to connect and control all sma\nrt home devices seamlessly. Our goal is\n to revolutionize home automation\n and establish ourselves as market leaders in this \ngrowing sector.\n2\nObjectives\n1. To introduce the SmartHome Hub and its \nkey features.\n2. To present market research findings and \ncompetitor analysis.\n3. To outline our marketing strategy and \nsales projections.'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2024-07-07T12:07:05+00:00', 'source': '../data/pdf/sample-5-page-pdf-a4-size.pdf', 'file_path': '../data/pdf/sample-5-page-pdf-a4-size.pdf', 'total_pages': 5, 'format': 'PDF 1.4', 'title': 'Sample 5-Page PDF A4 Size | Sample-Files.com', 'author': 'Jericho', 'subject': '', 'keywords': 'DAGKRGfiZEo,BAEVm-WErFA', 'moddate': '2024-07-07T12:07:04+00:00', 'trapped': '', 'modDate': "D:20240707120704+00'00'", 'creationDate': "D:20240707120705+00'00'", 'page': 2}, page_content='3\nKey Features\n1. Universal Compatibility: Works with all \nmajor smart home brands.\n2. AI-Powered Assistant: Learns user habits \nfor proactive home management.\n3. Enhanced Security: Military-grade \nencryption for data protection.\nMarket Analysis\nThe global smart home market is projected\n to reach $135.3 billion by 2025, growing at a \nCAGR of 11.6% from 2020 to 2025.'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2024-07-07T12:07:05+00:00', 'source': '../data/pdf/sample-5-page-pdf-a4-size.pdf', 'file_path': '../data/pdf/sample-5-page-pdf-a4-size.pdf', 'total_pages': 5, 'format': 'PDF 1.4', 'title': 'Sample 5-Page PDF A4 Size | Sample-Files.com', 'author': 'Jericho', 'subject': '', 'keywords': 'DAGKRGfiZEo,BAEVm-WErFA', 'moddate': '2024-07-07T12:07:04+00:00', 'trapped': '', 'modDate': "D:20240707120704+00'00'", 'creationDate': "D:20240707120705+00'00'", 'page': 3}, page_content='4\nCompetitor Analysis\nCompany Market Share Key Differentiator\nSmartTech Co. 35% Wide range of \nproprietary devices\nHomeGenius 28% User-friendly interface\nConnectAll 18% Low-cost options\nOur Solution 19% Universal compatibility \n& AI integration\nMarketing Strategy\n1. Digital Marketing: Targeted social media \ncampaigns and influencer partnerships.\n2. Trade Shows: Showcase at CES and IFA.\n3. Retail Partnerships: In-store demos at \nmajor electronics retailers.'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2024-07-07T12:07:05+00:00', 'source': '../data/pdf/sample-5-page-pdf-a4-size.pdf', 'file_path': '../data/pdf/sample-5-page-pdf-a4-size.pdf', 'total_pages': 5, 'format': 'PDF 1.4', 'title': 'Sample 5-Page PDF A4 Size | Sample-Files.com', 'author': 'Jericho', 'subject': '', 'keywords': 'DAGKRGfiZEo,BAEVm-WErFA', 'moddate': '2024-07-07T12:07:04+00:00', 'trapped': '', 'modDate': "D:20240707120704+00'00'", 'creationDate': "D:20240707120705+00'00'", 'page': 4}, page_content='5\nConclusion\nThe SmartHome Hub represents a significant\n opportunity for Innovative Tech Solutions t\no capture a substantial share of the rapid\nly growing smart home market. With \nour unique features and strategic marke\nting plan, we are well-positioned for a succe\nssful product launch. \nNext Steps\n1. Finalize production agreements with \nmanufacturers.\n2. Launch pre-order website and marketing \ncampaign.\n3. Prepare for the official launch event.'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-03-29T10:27:51+00:00', 'source': '../data/pdf/dev-example.pdf', 'file_path': '../data/pdf/dev-example.pdf', 'total_pages': 6, 'format': 'PDF 1.4', 'title': 'Developer Example PDF (A4 Size) | Sample-Files.com', 'author': 'Jericho', 'subject': '', 'keywords': 'DAGjGmcpgUo,BAEVm-WErFA,0', 'moddate': '2025-03-29T10:27:50+00:00', 'trapped': '', 'modDate': "D:20250329102750+00'00'", 'creationDate': "D:20250329102751+00'00'", 'page': 0}, page_content='Sample Team\nPrepared By:\nsample-files.com\nPDF Example\nfor Developers\nWebsite:'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-03-29T10:27:51+00:00', 'source': '../data/pdf/dev-example.pdf', 'file_path': '../data/pdf/dev-example.pdf', 'total_pages': 6, 'format': 'PDF 1.4', 'title': 'Developer Example PDF (A4 Size) | Sample-Files.com', 'author': 'Jericho', 'subject': '', 'keywords': 'DAGjGmcpgUo,BAEVm-WErFA,0', 'moddate': '2025-03-29T10:27:50+00:00', 'trapped': '', 'modDate': "D:20250329102750+00'00'", 'creationDate': "D:20250329102751+00'00'", 'page': 1}, page_content='This document is designed to showcase\nvarious features available for PDF generation\nand manipulation. It includes formatted text,\ntables, images, hyperlinks, and more.\nPDF Example for Developers\nThis sample PDF file is provided by Sample-Files.com. Visit us for more sample files and resource.'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-03-29T10:27:51+00:00', 'source': '../data/pdf/dev-example.pdf', 'file_path': '../data/pdf/dev-example.pdf', 'total_pages': 6, 'format': 'PDF 1.4', 'title': 'Developer Example PDF (A4 Size) | Sample-Files.com', 'author': 'Jericho', 'subject': '', 'keywords': 'DAGjGmcpgUo,BAEVm-WErFA,0', 'moddate': '2025-03-29T10:27:50+00:00', 'trapped': '', 'modDate': "D:20250329102750+00'00'", 'creationDate': "D:20250329102751+00'00'", 'page': 2}, page_content='Bold Text, Italicized Text, and Underlined Text\ncan be used to emphasize content.\nPDF Example for Developers\nThis sample PDF file is provided by Sample-Files.com. Visit us for more sample files and resource.\nBullet Points:\nSupport for styled text\nBullet and numbered lists\nCustom fonts and colors\nRich text formatting\nNumbered Lists:\n Support for styled text\n1.\n Bullet and numbered lists\n2.\n Custom fonts and colors\n3.\n Rich text formatting\n4.'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-03-29T10:27:51+00:00', 'source': '../data/pdf/dev-example.pdf', 'file_path': '../data/pdf/dev-example.pdf', 'total_pages': 6, 'format': 'PDF 1.4', 'title': 'Developer Example PDF (A4 Size) | Sample-Files.com', 'author': 'Jericho', 'subject': '', 'keywords': 'DAGjGmcpgUo,BAEVm-WErFA,0', 'moddate': '2025-03-29T10:27:50+00:00', 'trapped': '', 'modDate': "D:20250329102750+00'00'", 'creationDate': "D:20250329102751+00'00'", 'page': 3}, page_content='Tables and Data Display\nThis sample PDF file is provided by Sample-Files.com. Visit us for more sample files and resource.\nID\nName\nRole\nDepartment\n001\nJohn Doe\nDeveloper\nEngineering\n002\nJane Smith\nDesigner\nCreative\n003\nAlice Brown\nManager\nHR\nOfficia veniam nisi quis irure dolore elit tempor\nea aliquip culpa quis ullamco veniam. Minim\ndolore deserunt aliquip laborum culpa mollit\nanim cillum nostrud laborum veniam non\nvoluptate.\nReprehenderit sit pariatur reprehenderit non\nsint aliqua est reprehenderit. Incididunt\ncommodo enim magna magna ipsum voluptate\naute voluptate.'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-03-29T10:27:51+00:00', 'source': '../data/pdf/dev-example.pdf', 'file_path': '../data/pdf/dev-example.pdf', 'total_pages': 6, 'format': 'PDF 1.4', 'title': 'Developer Example PDF (A4 Size) | Sample-Files.com', 'author': 'Jericho', 'subject': '', 'keywords': 'DAGjGmcpgUo,BAEVm-WErFA,0', 'moddate': '2025-03-29T10:27:50+00:00', 'trapped': '', 'modDate': "D:20250329102750+00'00'", 'creationDate': "D:20250329102751+00'00'", 'page': 4}, page_content='Images and Hyperlinks\nThis sample PDF file is provided by Sample-Files.com. Visit us for more sample files and resource.\nBelow is an example image inserted into the\nPDF:\nVisit Sample-Files.com for more sample documents.'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-03-29T10:27:51+00:00', 'source': '../data/pdf/dev-example.pdf', 'file_path': '../data/pdf/dev-example.pdf', 'total_pages': 6, 'format': 'PDF 1.4', 'title': 'Developer Example PDF (A4 Size) | Sample-Files.com', 'author': 'Jericho', 'subject': '', 'keywords': 'DAGjGmcpgUo,BAEVm-WErFA,0', 'moddate': '2025-03-29T10:27:50+00:00', 'trapped': '', 'modDate': "D:20250329102750+00'00'", 'creationDate': "D:20250329102751+00'00'", 'page': 5}, page_content='Forms and Annotations\nOverview\nThis sample PDF file is provided by Sample-Files.com. Visit us for more sample files and resource.\nForms allow users to input information directly into a PDF\ndocument. Annotations can be used to highlight,\ncomment, or mark up specific sections of the document.\nForm Elements:\nText Fields\nRadio Buttons\nYes\nNo\nCheckboxes'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-03-29T06:50:10+00:00', 'source': '../data/pdf/image-doc.pdf', 'file_path': '../data/pdf/image-doc.pdf', 'total_pages': 6, 'format': 'PDF 1.4', 'title': 'Image-Heavy PDF (A4 Size) | Sample-Files.com', 'author': 'Jericho', 'subject': '', 'keywords': 'DAGjFrjVdxQ,BAEVm-WErFA,0', 'moddate': '2025-03-29T06:50:09+00:00', 'trapped': '', 'modDate': "D:20250329065009+00'00'", 'creationDate': "D:20250329065010+00'00'", 'page': 0}, page_content='Sample Team\nPrepared By:\nsample-files.com\nImage-Heavy\nPDF\nWebsite:'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-03-29T06:50:10+00:00', 'source': '../data/pdf/image-doc.pdf', 'file_path': '../data/pdf/image-doc.pdf', 'total_pages': 6, 'format': 'PDF 1.4', 'title': 'Image-Heavy PDF (A4 Size) | Sample-Files.com', 'author': 'Jericho', 'subject': '', 'keywords': 'DAGjFrjVdxQ,BAEVm-WErFA,0', 'moddate': '2025-03-29T06:50:09+00:00', 'trapped': '', 'modDate': "D:20250329065009+00'00'", 'creationDate': "D:20250329065010+00'00'", 'page': 1}, page_content='Nature Landscape\nA beautiful landscape showcasing the wonders of\nnature.\nThis sample PDF file is provided by Sample-Files.com. Visit us for more sample files and resource.'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-03-29T06:50:10+00:00', 'source': '../data/pdf/image-doc.pdf', 'file_path': '../data/pdf/image-doc.pdf', 'total_pages': 6, 'format': 'PDF 1.4', 'title': 'Image-Heavy PDF (A4 Size) | Sample-Files.com', 'author': 'Jericho', 'subject': '', 'keywords': 'DAGjFrjVdxQ,BAEVm-WErFA,0', 'moddate': '2025-03-29T06:50:09+00:00', 'trapped': '', 'modDate': "D:20250329065009+00'00'", 'creationDate': "D:20250329065010+00'00'", 'page': 2}, page_content='City Skyline\nA high-resolution image of a bustling city skyline at\nnight.\nThis sample PDF file is provided by Sample-Files.com. Visit us for more sample files and resource.'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-03-29T06:50:10+00:00', 'source': '../data/pdf/image-doc.pdf', 'file_path': '../data/pdf/image-doc.pdf', 'total_pages': 6, 'format': 'PDF 1.4', 'title': 'Image-Heavy PDF (A4 Size) | Sample-Files.com', 'author': 'Jericho', 'subject': '', 'keywords': 'DAGjFrjVdxQ,BAEVm-WErFA,0', 'moddate': '2025-03-29T06:50:09+00:00', 'trapped': '', 'modDate': "D:20250329065009+00'00'", 'creationDate': "D:20250329065010+00'00'", 'page': 3}, page_content='Wildlife Photography\nAn up-close capture of wildlife in their natural habitat.\nThis sample PDF file is provided by Sample-Files.com. Visit us for more sample files and resource.'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-03-29T06:50:10+00:00', 'source': '../data/pdf/image-doc.pdf', 'file_path': '../data/pdf/image-doc.pdf', 'total_pages': 6, 'format': 'PDF 1.4', 'title': 'Image-Heavy PDF (A4 Size) | Sample-Files.com', 'author': 'Jericho', 'subject': '', 'keywords': 'DAGjFrjVdxQ,BAEVm-WErFA,0', 'moddate': '2025-03-29T06:50:09+00:00', 'trapped': '', 'modDate': "D:20250329065009+00'00'", 'creationDate': "D:20250329065010+00'00'", 'page': 4}, page_content='Space Exploration\nAn artistic representation of space exploration and\ngalaxies.\nThis sample PDF file is provided by Sample-Files.com. Visit us for more sample files and resource.'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-03-29T06:50:10+00:00', 'source': '../data/pdf/image-doc.pdf', 'file_path': '../data/pdf/image-doc.pdf', 'total_pages': 6, 'format': 'PDF 1.4', 'title': 'Image-Heavy PDF (A4 Size) | Sample-Files.com', 'author': 'Jericho', 'subject': '', 'keywords': 'DAGjFrjVdxQ,BAEVm-WErFA,0', 'moddate': '2025-03-29T06:50:09+00:00', 'trapped': '', 'modDate': "D:20250329065009+00'00'", 'creationDate': "D:20250329065010+00'00'", 'page': 5}, page_content='Underwater World\nA breathtaking view of marine life deep beneath the\nocean.\nThis sample PDF file is provided by Sample-Files.com. Visit us for more sample files and resource.')]
