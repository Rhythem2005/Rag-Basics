# %%
import os
from langchain_community.document_loaders import PyPDFLoader, PyMuPDFLoader
from pathlib import Path

# %%
### Read all the pdf's inside the directory
def process_all_pdfs(pdf_directory):
    """Process all PDF files in a directory"""
    all_documents = []
    pdf_dir = Path(pdf_directory)
    
    # Find all PDF files recursively
    pdf_files = list(pdf_dir.glob("**/*.pdf"))
    
    print(f"Found {len(pdf_files)} PDF files to process")
    
    for pdf_file in pdf_files:
        print(f"\nProcessing: {pdf_file.name}")
        try:
            loader = PyPDFLoader(str(pdf_file))
            documents = loader.load()
            
            # Add source information to metadata
            for doc in documents:
                doc.metadata['source_file'] = pdf_file.name
                doc.metadata['file_type'] = 'pdf'
            
            all_documents.extend(documents)
            print(f"  ✓ Loaded {len(documents)} pages")
            
        except Exception as e:
            print(f"  ✗ Error: {e}")
    
    print(f"\nTotal documents loaded: {len(all_documents)}")
    return all_documents

# Process all PDFs in the data directory
all_pdf_documents = process_all_pdfs("../data")
# Out:
# Found 4 PDF files to process
#
# Processing: sample-10-page-pdf-a4-size.pdf
#   ✓ Loaded 10 pages
#
# Processing: sample-5-page-pdf-a4-size.pdf
#   ✓ Loaded 5 pages
#
# Processing: dev-example.pdf
#   ✓ Loaded 6 pages
#
# Processing: image-doc.pdf
#   ✓ Loaded 6 pages
#
# Total documents loaded: 27

# %%
all_pdf_documents
# Out:
# [Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2024-07-07T12:50:10+00:00', 'title': 'Sample 10-Page PDF A4 Size | Sample-Files.com', 'moddate': '2024-07-07T12:50:09+00:00', 'keywords': 'DAGKQlAebtI,BAEVm-WErFA', 'author': 'Jericho', 'source': '../data/pdf/sample-10-page-pdf-a4-size.pdf', 'total_pages': 10, 'page': 0, 'page_label': '1', 'source_file': 'sample-10-page-pdf-a4-size.pdf', 'file_type': 'pdf'}, page_content='SmartHome Hub\nSmartHome Hub, Inc\nAlex Johnson\nPrepared By\nhttps://sample-files.com+123-456-7890\nProduct Launch Strategy'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2024-07-07T12:50:10+00:00', 'title': 'Sample 10-Page PDF A4 Size | Sample-Files.com', 'moddate': '2024-07-07T12:50:09+00:00', 'keywords': 'DAGKQlAebtI,BAEVm-WErFA', 'author': 'Jericho', 'source': '../data/pdf/sample-10-page-pdf-a4-size.pdf', 'total_pages': 10, 'page': 1, 'page_label': '2', 'source_file': 'sample-10-page-pdf-a4-size.pdf', 'file_type': 'pdf'}, page_content='Table of Contents\n1. Executive Summary\n2. Introduction\n3. Product Overview\n4. Market Analysis\n5. Competitor Analysis\n6. Marketing Strategy\n7. Sales Projections\n8. Launch Timeline'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2024-07-07T12:50:10+00:00', 'title': 'Sample 10-Page PDF A4 Size | Sample-Files.com', 'moddate': '2024-07-07T12:50:09+00:00', 'keywords': 'DAGKQlAebtI,BAEVm-WErFA', 'author': 'Jericho', 'source': '../data/pdf/sample-10-page-pdf-a4-size.pdf', 'total_pages': 10, 'page': 2, 'page_label': '3', 'source_file': 'sample-10-page-pdf-a4-size.pdf', 'file_type': 'pdf'}, page_content='Executive Summary\nLorem ipsum dolor sit amet, consectetur adipiscing\nelit. Cras facilisis consectetur tempor. Aenean aliquet\nsapien ex, pharetra consequat arcu tristique vitae.\nNam quis porta ex. Donec porttitor at sem nec\nsollicitudin. Ut vel commodo tortor, sagittis egestas\nnisl. Donec quam mauris, tristique non tempus vitae,\nornare sed mauris. Etiam blandit tempor metus, at\nvehicula nisi. Maecenas suscipit vulputate varius.\nNam lacinia leo felis, quis hendrerit tortor dignissim\nquis. Morbi egestas rhoncus lectus. Ut nec mauris\ndiam. Aenean gravida, est non ornare interdum, libero\nnibh accumsan nibh, sed commodo erat orci ac tellus.\nAenean iaculis urna nec metus sodales consectetur.\nQuisque lacinia dui vitae purus condimentum dapibus.\nPellentesque habitant morbi tristique senectus et\nnetus et malesuada fames ac turpis egestas.'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2024-07-07T12:50:10+00:00', 'title': 'Sample 10-Page PDF A4 Size | Sample-Files.com', 'moddate': '2024-07-07T12:50:09+00:00', 'keywords': 'DAGKQlAebtI,BAEVm-WErFA', 'author': 'Jericho', 'source': '../data/pdf/sample-10-page-pdf-a4-size.pdf', 'total_pages': 10, 'page': 3, 'page_label': '4', 'source_file': 'sample-10-page-pdf-a4-size.pdf', 'file_type': 'pdf'}, page_content='Introduction\nNam quis porta ex. Donec porttitor at sem nec\nsollicitudin. Ut vel commodo tortor, sagittis egestas\nnisl. Donec quam mauris, tristique non tempus vitae,\nornare sed mauris. Etiam blandit tempor metus, at\nvehicula nisi. Maecenas suscipit vulputate varius.'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2024-07-07T12:50:10+00:00', 'title': 'Sample 10-Page PDF A4 Size | Sample-Files.com', 'moddate': '2024-07-07T12:50:09+00:00', 'keywords': 'DAGKQlAebtI,BAEVm-WErFA', 'author': 'Jericho', 'source': '../data/pdf/sample-10-page-pdf-a4-size.pdf', 'total_pages': 10, 'page': 4, 'page_label': '5', 'source_file': 'sample-10-page-pdf-a4-size.pdf', 'file_type': 'pdf'}, page_content='Product Overview\nNam quis porta ex. Donec porttitor at sem nec\nsollicitudin. Ut vel commodo tortor, sagittis egestas\nnisl. Donec quam mauris, tristique non tempus vitae,\nornare sed mauris. Etiam blandit tempor metus, at\nvehicula nisi. Maecenas suscipit vulputate varius.\nInteger et justo velus.\nUt in ipsum ac risus.\nMaecenas iaculis.\nUt nec mauris vel.\nTellus accumsan.\nKey Features\nInteger et justo velus.\nUt in ipsum ac risus.\nMaecenas iaculis.\nUt nec mauris vel.\nTellus accumsan.\nKey Features'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2024-07-07T12:50:10+00:00', 'title': 'Sample 10-Page PDF A4 Size | Sample-Files.com', 'moddate': '2024-07-07T12:50:09+00:00', 'keywords': 'DAGKQlAebtI,BAEVm-WErFA', 'author': 'Jericho', 'source': '../data/pdf/sample-10-page-pdf-a4-size.pdf', 'total_pages': 10, 'page': 5, 'page_label': '6', 'source_file': 'sample-10-page-pdf-a4-size.pdf', 'file_type': 'pdf'}, page_content='Market Analysis\nNam quis porta ex. Donec porttitor at sem nec\nsollicitudin. Ut vel commodo tortor, sagittis egestas\nnisl. Donec quam mauris, tristique non tempus vitae,\nornare sed mauris. Etiam blandit tempor metus, at\nvehicula nisi. Maecenas suscipit vulputate varius.\nCurrent market share Projected sales for the\nfirst three years'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2024-07-07T12:50:10+00:00', 'title': 'Sample 10-Page PDF A4 Size | Sample-Files.com', 'moddate': '2024-07-07T12:50:09+00:00', 'keywords': 'DAGKQlAebtI,BAEVm-WErFA', 'author': 'Jericho', 'source': '../data/pdf/sample-10-page-pdf-a4-size.pdf', 'total_pages': 10, 'page': 6, 'page_label': '7', 'source_file': 'sample-10-page-pdf-a4-size.pdf', 'file_type': 'pdf'}, page_content='Competitor Analysis\nVivamus orci mi, venenatis quis diam sed, scelerisque\naccumsan lacus. Curabitur eu dictum neque, sit amet\nrutrum velit. In aliquam orci a ante hendrerit, vel\negestas ligula interdum. Ut pulvinar ornare dapibus.\nSuspendisse nec cursus libero, at hendrerit eros.'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2024-07-07T12:50:10+00:00', 'title': 'Sample 10-Page PDF A4 Size | Sample-Files.com', 'moddate': '2024-07-07T12:50:09+00:00', 'keywords': 'DAGKQlAebtI,BAEVm-WErFA', 'author': 'Jericho', 'source': '../data/pdf/sample-10-page-pdf-a4-size.pdf', 'total_pages': 10, 'page': 7, 'page_label': '8', 'source_file': 'sample-10-page-pdf-a4-size.pdf', 'file_type': 'pdf'}, page_content='Marketing Strategy\nTristique non tempus vitae, ornare sed mauris. Etiam\nblandit tempor metus, at vehicula nisi. Maecenas\nsuscipit vulputate varius.\nInteger et justo velus.\nUt in ipsum ac risus.\nMaecenas iaculis.\nUt nec mauris vel.\nTellus accumsan.\n1st Strategy\nInteger et justo velus.\nUt in ipsum ac risus.\nMaecenas iaculis.\nUt nec mauris vel.\nTellus accumsan.\n 2nd Strategy'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2024-07-07T12:50:10+00:00', 'title': 'Sample 10-Page PDF A4 Size | Sample-Files.com', 'moddate': '2024-07-07T12:50:09+00:00', 'keywords': 'DAGKQlAebtI,BAEVm-WErFA', 'author': 'Jericho', 'source': '../data/pdf/sample-10-page-pdf-a4-size.pdf', 'total_pages': 10, 'page': 8, 'page_label': '9', 'source_file': 'sample-10-page-pdf-a4-size.pdf', 'file_type': 'pdf'}, page_content='Sales Projections\nTristique non tempus vitae, ornare sed mauris. Etiam\nblandit tempor metus, at vehicula nisi. Maecenas\nsuscipit vulputate varius.\nMetric Sales\nMarket Size $50 Billion\nUser Satisfaction 85%\nGrowth Rate 10%\nSeries 1 Series 2\nItem 1 Item 2 Item 30\n5\n10\n15\n20'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2024-07-07T12:50:10+00:00', 'title': 'Sample 10-Page PDF A4 Size | Sample-Files.com', 'moddate': '2024-07-07T12:50:09+00:00', 'keywords': 'DAGKQlAebtI,BAEVm-WErFA', 'author': 'Jericho', 'source': '../data/pdf/sample-10-page-pdf-a4-size.pdf', 'total_pages': 10, 'page': 9, 'page_label': '10', 'source_file': 'sample-10-page-pdf-a4-size.pdf', 'file_type': 'pdf'}, page_content='Launch Timeline\nVivamus ac nunc vitae nulla molestie sodales. Proin sit\namet rhoncus lacus. Cras non erat imperdiet sapien\nporttitor aliquam nec ut velit.'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2024-07-07T12:07:05+00:00', 'title': 'Sample 5-Page PDF A4 Size | Sample-Files.com', 'moddate': '2024-07-07T12:07:04+00:00', 'keywords': 'DAGKRGfiZEo,BAEVm-WErFA', 'author': 'Jericho', 'source': '../data/pdf/sample-5-page-pdf-a4-size.pdf', 'total_pages': 5, 'page': 0, 'page_label': '1', 'source_file': 'sample-5-page-pdf-a4-size.pdf', 'file_type': 'pdf'}, page_content='Innovative Tech\nSolutions, Inc.\nProduct Launch Report:\nSmartHome Hub\nPrepared by:\nAlex Johnson\nsample-files.com\n+1-555-123-4567'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2024-07-07T12:07:05+00:00', 'title': 'Sample 5-Page PDF A4 Size | Sample-Files.com', 'moddate': '2024-07-07T12:07:04+00:00', 'keywords': 'DAGKRGfiZEo,BAEVm-WErFA', 'author': 'Jericho', 'source': '../data/pdf/sample-5-page-pdf-a4-size.pdf', 'total_pages': 5, 'page': 1, 'page_label': '2', 'source_file': 'sample-5-page-pdf-a4-size.pdf', 'file_type': 'pdf'}, page_content='Introduction\nThis report outlines the launch strategy for\nour new SmartHome Hub, a central device\ndesigned to connect and control all smart\nhome devices seamlessly. Our goal is to\nrevolutionize home automation and\nestablish ourselves as market leaders in this\ngrowing sector.\n2\nObjectives\n1. To introduce the SmartHome Hub and its\nkey features.\n2. To present market research findings and\ncompetitor analysis.\n3. To outline our marketing strategy and\nsales projections.'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2024-07-07T12:07:05+00:00', 'title': 'Sample 5-Page PDF A4 Size | Sample-Files.com', 'moddate': '2024-07-07T12:07:04+00:00', 'keywords': 'DAGKRGfiZEo,BAEVm-WErFA', 'author': 'Jericho', 'source': '../data/pdf/sample-5-page-pdf-a4-size.pdf', 'total_pages': 5, 'page': 2, 'page_label': '3', 'source_file': 'sample-5-page-pdf-a4-size.pdf', 'file_type': 'pdf'}, page_content='3\nKey Features\n1. Universal Compatibility: Works with all\nmajor smart home brands.\n2. AI-Powered Assistant: Learns user habits\nfor proactive home management.\n3. Enhanced Security: Military-grade\nencryption for data protection.\nMarket Analysis\nThe global smart home market is projected\nto reach $135.3 billion by 2025, growing at a\nCAGR of 11.6% from 2020 to 2025.'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2024-07-07T12:07:05+00:00', 'title': 'Sample 5-Page PDF A4 Size | Sample-Files.com', 'moddate': '2024-07-07T12:07:04+00:00', 'keywords': 'DAGKRGfiZEo,BAEVm-WErFA', 'author': 'Jericho', 'source': '../data/pdf/sample-5-page-pdf-a4-size.pdf', 'total_pages': 5, 'page': 3, 'page_label': '4', 'source_file': 'sample-5-page-pdf-a4-size.pdf', 'file_type': 'pdf'}, page_content='4\nCompetitor Analysis\nCompany Market Share Key Differentiator\nSmartTech Co. 35% Wide range of\nproprietary devices\nHomeGenius 28% User-friendly interface\nConnectAll 18% Low-cost options\nOur Solution 19% Universal compatibility\n& AI integration\nMarketing Strategy\n1. Digital Marketing: Targeted social media\ncampaigns and influencer partnerships.\n2. Trade Shows: Showcase at CES and IFA.\n3. Retail Partnerships: In-store demos at\nmajor electronics retailers.'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2024-07-07T12:07:05+00:00', 'title': 'Sample 5-Page PDF A4 Size | Sample-Files.com', 'moddate': '2024-07-07T12:07:04+00:00', 'keywords': 'DAGKRGfiZEo,BAEVm-WErFA', 'author': 'Jericho', 'source': '../data/pdf/sample-5-page-pdf-a4-size.pdf', 'total_pages': 5, 'page': 4, 'page_label': '5', 'source_file': 'sample-5-page-pdf-a4-size.pdf', 'file_type': 'pdf'}, page_content='5\nConclusion\nThe SmartHome Hub represents a significant\nopportunity for Innovative Tech Solutions to\ncapture a substantial share of the rapidly\ngrowing smart home market. With our\nunique features and strategic marketing\nplan, we are well-positioned for a successful\nproduct launch. \nNext Steps\n1. Finalize production agreements with\nmanufacturers.\n2. Launch pre-order website and marketing\ncampaign.\n3. Prepare for the official launch event.'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-03-29T10:27:51+00:00', 'title': 'Developer Example PDF (A4 Size) | Sample-Files.com', 'moddate': '2025-03-29T10:27:50+00:00', 'keywords': 'DAGjGmcpgUo,BAEVm-WErFA,0', 'author': 'Jericho', 'source': '../data/pdf/dev-example.pdf', 'total_pages': 6, 'page': 0, 'page_label': '1', 'source_file': 'dev-example.pdf', 'file_type': 'pdf'}, page_content='Sample Team\nPrepared By:\nsample-files.com\nPDF Example\nfor Developers\nWebsite:'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-03-29T10:27:51+00:00', 'title': 'Developer Example PDF (A4 Size) | Sample-Files.com', 'moddate': '2025-03-29T10:27:50+00:00', 'keywords': 'DAGjGmcpgUo,BAEVm-WErFA,0', 'author': 'Jericho', 'source': '../data/pdf/dev-example.pdf', 'total_pages': 6, 'page': 1, 'page_label': '2', 'source_file': 'dev-example.pdf', 'file_type': 'pdf'}, page_content='This document is designed to showcase\nvarious features available for PDF generation\nand manipulation. It includes formatted text,\ntables, images, hyperlinks, and more.\nPDF Example for Developers\nThis sample PDF file is provided by Sample-Files.com. Visit us for more sample files and resource.'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-03-29T10:27:51+00:00', 'title': 'Developer Example PDF (A4 Size) | Sample-Files.com', 'moddate': '2025-03-29T10:27:50+00:00', 'keywords': 'DAGjGmcpgUo,BAEVm-WErFA,0', 'author': 'Jericho', 'source': '../data/pdf/dev-example.pdf', 'total_pages': 6, 'page': 2, 'page_label': '3', 'source_file': 'dev-example.pdf', 'file_type': 'pdf'}, page_content='Bold Text, Italicized Text, and Underlined Text\ncan be used to emphasize content.\nPDF Example for Developers\nThis sample PDF file is provided by Sample-Files.com. Visit us for more sample files and resource.\nBullet Points:\nSupport for styled text\nBullet and numbered lists\nCustom fonts and colors\nRich text formatting\nNumbered Lists:\n Support for styled text1.\n Bullet and numbered lists2.\n Custom fonts and colors3.\n Rich text formatting4.'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-03-29T10:27:51+00:00', 'title': 'Developer Example PDF (A4 Size) | Sample-Files.com', 'moddate': '2025-03-29T10:27:50+00:00', 'keywords': 'DAGjGmcpgUo,BAEVm-WErFA,0', 'author': 'Jericho', 'source': '../data/pdf/dev-example.pdf', 'total_pages': 6, 'page': 3, 'page_label': '4', 'source_file': 'dev-example.pdf', 'file_type': 'pdf'}, page_content='Tables and Data Display\nThis sample PDF file is provided by Sample-Files.com. Visit us for more sample files and resource.\nID Name Role Department\n001 John Doe Developer Engineering\n002 Jane Smith Designer Creative\n003 Alice Brown Manager HR\nOfficia veniam nisi quis irure dolore elit tempor\nea aliquip culpa quis ullamco veniam. Minim\ndolore deserunt aliquip laborum culpa mollit\nanim cillum nostrud laborum veniam non\nvoluptate.\nReprehenderit sit pariatur reprehenderit non\nsint aliqua est reprehenderit. Incididunt\ncommodo enim magna magna ipsum voluptate\naute voluptate.'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-03-29T10:27:51+00:00', 'title': 'Developer Example PDF (A4 Size) | Sample-Files.com', 'moddate': '2025-03-29T10:27:50+00:00', 'keywords': 'DAGjGmcpgUo,BAEVm-WErFA,0', 'author': 'Jericho', 'source': '../data/pdf/dev-example.pdf', 'total_pages': 6, 'page': 4, 'page_label': '5', 'source_file': 'dev-example.pdf', 'file_type': 'pdf'}, page_content='Images and Hyperlinks\nThis sample PDF file is provided by Sample-Files.com. Visit us for more sample files and resource.\nBelow is an example image inserted into the\nPDF:\nVisit Sample-Files.com for more sample documents.'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-03-29T10:27:51+00:00', 'title': 'Developer Example PDF (A4 Size) | Sample-Files.com', 'moddate': '2025-03-29T10:27:50+00:00', 'keywords': 'DAGjGmcpgUo,BAEVm-WErFA,0', 'author': 'Jericho', 'source': '../data/pdf/dev-example.pdf', 'total_pages': 6, 'page': 5, 'page_label': '6', 'source_file': 'dev-example.pdf', 'file_type': 'pdf'}, page_content='Forms and Annotations\nOverview\nThis sample PDF file is provided by Sample-Files.com. Visit us for more sample files and resource.\nForms allow users to input information directly into a PDF\ndocument. Annotations can be used to highlight,\ncomment, or mark up specific sections of the document.\nForm Elements:\nText Fields\nRadio Buttons\nYes No\nCheckboxes'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-03-29T06:50:10+00:00', 'title': 'Image-Heavy PDF (A4 Size) | Sample-Files.com', 'moddate': '2025-03-29T06:50:09+00:00', 'keywords': 'DAGjFrjVdxQ,BAEVm-WErFA,0', 'author': 'Jericho', 'source': '../data/pdf/image-doc.pdf', 'total_pages': 6, 'page': 0, 'page_label': '1', 'source_file': 'image-doc.pdf', 'file_type': 'pdf'}, page_content='Sample Team\nPrepared By:\nsample-files.com\nImage-Heavy\nPDF\nWebsite:'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-03-29T06:50:10+00:00', 'title': 'Image-Heavy PDF (A4 Size) | Sample-Files.com', 'moddate': '2025-03-29T06:50:09+00:00', 'keywords': 'DAGjFrjVdxQ,BAEVm-WErFA,0', 'author': 'Jericho', 'source': '../data/pdf/image-doc.pdf', 'total_pages': 6, 'page': 1, 'page_label': '2', 'source_file': 'image-doc.pdf', 'file_type': 'pdf'}, page_content='Nature Landscape\nA beautiful landscape showcasing the wonders of\nnature.\nThis sample PDF file is provided by Sample-Files.com. Visit us for more sample files and resource.'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-03-29T06:50:10+00:00', 'title': 'Image-Heavy PDF (A4 Size) | Sample-Files.com', 'moddate': '2025-03-29T06:50:09+00:00', 'keywords': 'DAGjFrjVdxQ,BAEVm-WErFA,0', 'author': 'Jericho', 'source': '../data/pdf/image-doc.pdf', 'total_pages': 6, 'page': 2, 'page_label': '3', 'source_file': 'image-doc.pdf', 'file_type': 'pdf'}, page_content='City Skyline\nA high-resolution image of a bustling city skyline at\nnight.\nThis sample PDF file is provided by Sample-Files.com. Visit us for more sample files and resource.'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-03-29T06:50:10+00:00', 'title': 'Image-Heavy PDF (A4 Size) | Sample-Files.com', 'moddate': '2025-03-29T06:50:09+00:00', 'keywords': 'DAGjFrjVdxQ,BAEVm-WErFA,0', 'author': 'Jericho', 'source': '../data/pdf/image-doc.pdf', 'total_pages': 6, 'page': 3, 'page_label': '4', 'source_file': 'image-doc.pdf', 'file_type': 'pdf'}, page_content='Wildlife Photography\nAn up-close capture of wildlife in their natural habitat.\nThis sample PDF file is provided by Sample-Files.com. Visit us for more sample files and resource.'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-03-29T06:50:10+00:00', 'title': 'Image-Heavy PDF (A4 Size) | Sample-Files.com', 'moddate': '2025-03-29T06:50:09+00:00', 'keywords': 'DAGjFrjVdxQ,BAEVm-WErFA,0', 'author': 'Jericho', 'source': '../data/pdf/image-doc.pdf', 'total_pages': 6, 'page': 4, 'page_label': '5', 'source_file': 'image-doc.pdf', 'file_type': 'pdf'}, page_content='Space Exploration\nAn artistic representation of space exploration and\ngalaxies.\nThis sample PDF file is provided by Sample-Files.com. Visit us for more sample files and resource.'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-03-29T06:50:10+00:00', 'title': 'Image-Heavy PDF (A4 Size) | Sample-Files.com', 'moddate': '2025-03-29T06:50:09+00:00', 'keywords': 'DAGjFrjVdxQ,BAEVm-WErFA,0', 'author': 'Jericho', 'source': '../data/pdf/image-doc.pdf', 'total_pages': 6, 'page': 5, 'page_label': '6', 'source_file': 'image-doc.pdf', 'file_type': 'pdf'}, page_content='Underwater World\nA breathtaking view of marine life deep beneath the\nocean.\nThis sample PDF file is provided by Sample-Files.com. Visit us for more sample files and resource.')]

# %%
### Text splitting get into chunks

def split_documents(documents,chunk_size=1000,chunk_overlap=200):
    """Split documents into smaller chunks for better RAG performance"""
    text_splitter = RecursiveCharacterTextSplitter(
        chunk_size=chunk_size,
        chunk_overlap=chunk_overlap,
        length_function=len,
        separators=["\n\n", "\n", " ", ""]
    )
    split_docs = text_splitter.split_documents(documents)
    print(f"Split {len(documents)} documents into {len(split_docs)} chunks")
    
    # Show example of a chunk
    if split_docs:
        print(f"\nExample chunk:")
        print(f"Content: {split_docs[0].page_content[:200]}...")
        print(f"Metadata: {split_docs[0].metadata}")
    
    return split_docs

# %%
chunks=split_documents(all_pdf_documents)
chunks
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 chunks=split_documents(all_pdf_documents)
#       2 chunks
#
# Cell In[5], line 5, in split_documents(documents, chunk_size, chunk_overlap)
#       3 def split_documents(documents,chunk_size=1000,chunk_overlap=200):
#       4     """Split documents into smaller chunks for better RAG performance"""
# ----> 5     text_splitter = RecursiveCharacterTextSplitter(
#       6         chunk_size=chunk_size,
#       7         chunk_overlap=chunk_overlap,
#       8         length_function=len,
#       9         separators=["\n\n", "\n", " ", ""]
#      10     )
#      11     split_docs = text_splitter.split_documents(documents)
#      12     print(f"Split {len(documents)} documents into {len(split_docs)} chunks")
#
# NameError: name 'RecursiveCharacterTextSplitter' is not defined
